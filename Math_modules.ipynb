# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepak1920-hub/phython.ipynb/blob/main/Math_modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
#Find the cube root of a given number using mathematical operations.
num=16
cube_root=num**(1/2)
print(cube_root)
# Out:
# 4.0

# %%
#Calculate the factorial of a number using math.factorial()
math.factorial(5)
# Out:
# 120

# %%
#Find the GCD (Greatest Common Divisor) of two numbers using math.gcd().
math.gcd(12,14)
# Out:
# 2

# %%
#Find the LCM of two numbers using math.lcm().
math.lcm(12,3)
# Out:
# 12

# %%
#Calculate the value of 5 raised to the power of 8 using math.pow()

math.pow(5,8)
# Out:
# 390625.0

# %%
#Find the absolute value of a negative decimal number using math.fabs().
math.fabs(-13.57)
# Out:
# 13.57

# %%
#Round a floating-point number up using math.ceil().
num=8.3
print(math.ceil(num))
# Out:
# 9

# %%
#Round a floating-point number down using math.floor().
num=18.9
print(math.floor(num))
# Out:
# 18

# %%
#Round a floating-point number to the nearest integer using round().
value=21.55
round(value)
# Out:
# 22

# %%
#Find the remainder of two numbers using math.fmod().
math.fmod(12,5)
# Out:
# 2.0

# %%
#Find the quotient and remainder using divmod().
a=25
b=85
quotient,remainder=divmod(a,b)
print("Quotient:", quotient)
print("Remainder:", remainder)
# Out:
# Quotient: 0
# Remainder: 25

# %%
#Calculate the sine, cosine, and tangent of 45 degrees.
angle = math.radians(35)

print("sine =", math.sin(angle))
print("cosine =", math.cos(angle))
print("tangent =", math.tan(angle))
# Out:
# sine = 0.573576436351046
# cosine = 0.8191520442889918
# tangent = 0.7002075382097097

# %%
#Convert an angle from degrees to radians.
angel=45
radians=math.radians(angel)
print(radians)
# Out:
# 0.7853981633974483

# %%
#Convert an angle from radians to degrees.
radian_value = 1.9809
degree_value = math.degrees(radian_value)

print(degree_value)
# Out:
# 113.49720963746478

# %%
#Find the logarithm (base 10) of a number using math.log10().
math.log10(10)
# Out:
# 1.0

# %%
#Find the natural logarithm of a number using math.log().
num=10
result=math.log(10)
print(result)
# Out:
# 2.302585092994046

# %%
#Calculate e raised to the power of x using math.exp().
x=5
result=math.exp(x)
print(result)
# Out:
# 148.4131591025766

# %%
#Find the value of π (pi) and Euler's number (e) from the math module.
math.pi
math.e

print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
#Find the distance between two points using math.dist().
math.dist((1,2),(3,4))
# Out:
# 2.8284271247461903

# %%
#Calculate the hypotenuse of a right triangle using math.hypot().
math.hypot(5,6)
# Out:
# 7.810249675906654

# %%
#Find the combination (nCr) using math.comb().
math.comb(5,2)
# Out:
# 10

# %%
#Find the permutation (nPr) using math.perm().
math.perm(5,2)
# Out:
# 20

# %%
#Find the product of all numbers in a list using math.prod().
num=[1,2,3,4,5]
result=math.prod(num)
print(result)
# Out:
# 120

# %%
#Find the sum of square roots of all numbers in a list.
num=[1,4,9,16]
result=sum(math.sqrt(num)for num in num)
print("sum of square roots=",num)
# Out:
# sum of square roots= [1, 4, 9, 16]

# %%
#Find the largest integer less than or equal to the square root of a given number.
num=(1,2,3,5)
result =[math.sqrt(x)for x in num]
print(result)
# Out:
# [1.0, 1.4142135623730951, 1.7320508075688772, 2.23606797749979]
