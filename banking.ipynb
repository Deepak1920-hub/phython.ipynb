# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepak1920-hub/phython.ipynb/blob/main/banking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bank = [ [ [ ["C101", "Rahul", "Savings", 85000], ["C102", "Anita", "Current", 150000], ["C103", "Kiran", "Loan", 500000] ], [ ["C104", "Sneha", "Savings", 95000], ["C105", "Vikram", "Current", 275000], ["C106", "Meena", "Loan", 750000] ] ],

[
    [
        ["C201", "Arjun", "Savings", 120000],
        ["C202", "Pooja", "Current", 325000],
        ["C203", "Ramesh", "Loan", 900000]
    ],
    [
        ["C204", "Priya", "Savings", 45000],
        ["C205", "Amit", "Current", 185000],
        ["C206", "Divya", "Loan", 650000]
    ]
],

[
    [
        ["C301", "Nikhil", "Savings", 78000],
        ["C302", "Kavya", "Current", 240000],
        ["C303", "Suresh", "Loan", 1000000]
    ],
    [
        ["C304", "Neha", "Savings", 135000],
        ["C305", "Rohan", "Current", 410000],
        ["C306", "Asha", "Loan", 550000]
    ]
]
]

# %%
bank[0][0][0]
# Out:
# ['C101', 'Rahul', 'Savings', 85000]

# %%
bank[0][0][1][2]
# Out:
# 'Current'

# %%
bank[0][0][2][3]
# Out:
# 500000

# %%
bank[0][1][0][0]
# Out:
# 'C104'

# %%
bank[0][1][1][3]
# Out:
# 275000

# %%
bank[0][1][2]
# Out:
# ['C106', 'Meena', 'Loan', 750000]

# %%
bank[1][0][0][0]
# Out:
# 'C201'

# %%
bank[1][0][1][1]
# Out:
# 'Pooja'

# %%
bank[1][0][2][2]
# Out:
# 'Loan'

# %%
bank[1][1][0][3]
# Out:
# 45000

# %%
bank[1][1][1][2]
# Out:
# 'Current'

# %%
bank[1][1][2][0]
# Out:
# 'C206'

# %%
bank[2][0][0][2]
# Out:
# 'Savings'

# %%
bank[2][0][1][3]
# Out:
# 240000

# %%
bank[2][0][2][3]
# Out:
# 1000000

# %%
bank[2][1][0][1]
# Out:
# 'Neha'

# %%
bank[2][1][1]
# Out:
# ['C305', 'Rohan', 'Current', 410000]

# %%
bank[2][1][2][2]
# Out:
# 'Loan'

# %%
bank[0][0]
# Out:
# [['C101', 'Rahul', 'Savings', 85000],
#  ['C102', 'Anita', 'Current', 150000],
#  ['C103', 'Kiran', 'Loan', 500000]]

# %%
bank[0][1]
# Out:
# [['C104', 'Sneha', 'Savings', 95000],
#  ['C105', 'Vikram', 'Current', 275000],
#  ['C106', 'Meena', 'Loan', 750000]]

# %%
bank[1][0]
# Out:
# [['C201', 'Arjun', 'Savings', 120000],
#  ['C202', 'Pooja', 'Current', 325000],
#  ['C203', 'Ramesh', 'Loan', 900000]]

# %%
bank[1][1]
# Out:
# [['C204', 'Priya', 'Savings', 45000],
#  ['C205', 'Amit', 'Current', 185000],
#  ['C206', 'Divya', 'Loan', 650000]]

# %%
bank[2][0]
# Out:
# [['C301', 'Nikhil', 'Savings', 78000],
#  ['C302', 'Kavya', 'Current', 240000],
#  ['C303', 'Suresh', 'Loan', 1000000]]

# %%
bank[2][1]
# Out:
# [['C304', 'Neha', 'Savings', 135000],
#  ['C305', 'Rohan', 'Current', 410000],
#  ['C306', 'Asha', 'Loan', 550000]]

# %%
bank[0]
# Out:
# [[['C101', 'Rahul', 'Savings', 85000],
#   ['C102', 'Anita', 'Current', 150000],
#   ['C103', 'Kiran', 'Loan', 500000]],
#  [['C104', 'Sneha', 'Savings', 95000],
#   ['C105', 'Vikram', 'Current', 275000],
#   ['C106', 'Meena', 'Loan', 750000]]]

# %%
bank[1]
# Out:
# [[['C201', 'Arjun', 'Savings', 120000],
#   ['C202', 'Pooja', 'Current', 325000],
#   ['C203', 'Ramesh', 'Loan', 900000]],
#  [['C204', 'Priya', 'Savings', 45000],
#   ['C205', 'Amit', 'Current', 185000],
#   ['C206', 'Divya', 'Loan', 650000]]]

# %%
bank[2]
# Out:
# [[['C301', 'Nikhil', 'Savings', 78000],
#   ['C302', 'Kavya', 'Current', 240000],
#   ['C303', 'Suresh', 'Loan', 1000000]],
#  [['C304', 'Neha', 'Savings', 135000],
#   ['C305', 'Rohan', 'Current', 410000],
#   ['C306', 'Asha', 'Loan', 550000]]]

# %%
bank[0][0][0],bank[1][0][0],bank[2][0][0]
# Out:
# (['C101', 'Rahul', 'Savings', 85000],
#  ['C201', 'Arjun', 'Savings', 120000],
#  ['C301', 'Nikhil', 'Savings', 78000])

# %%
bank[0][1][1],bank[1][1][1],bank[2][1][1]
# Out:
# (['C105', 'Vikram', 'Current', 275000],
#  ['C205', 'Amit', 'Current', 185000],
#  ['C305', 'Rohan', 'Current', 410000])

# %%
bank[2][1][2][3]
# Out:
# 550000
