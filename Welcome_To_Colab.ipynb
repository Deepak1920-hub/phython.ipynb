# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepak1920-hub/phython.ipynb/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = "Edukron Data Science and Data Engineering Batch 2026"

# %%
print(x[0:8])
# Out:
# Edukron

# %%
print(x[8:12])
# Out:
# Data

# %%
print(x[13:20])
# Out:
# Science

# %%
print(x[21:24])
# Out:
# and

# %%
print(x[25:41])
# Out:
# Data Engineering

# %%
print(x[30:41])
# Out:
# Engineering

# %%
print(x[42:47])
# Out:
# Batch

# %%
print(x[48:52])
# Out:
# 2026

# %%
print(x[13:29])
# Out:
# Science and Data

# %%
print(x[8:47])
# Out:
# Data Science and Data Engineering Batch
